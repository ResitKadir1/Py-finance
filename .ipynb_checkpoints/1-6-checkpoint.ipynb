# %%
#!pip install pandas-datareader

# %%
import yfinance as yf
import numpy as np
tslaQuote = yf.Ticker('TSLA')
tslaQuote.history(start="2010-01-01", end="2014-12-31")
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2010-06-29   3.800000   5.000000   3.508000   4.778000  93831500          0
# 2010-06-30   5.158000   6.084000   4.660000   4.766000  85935500          0
# 2010-07-01   5.000000   5.184000   4.054000   4.392000  41094000          0
# 2010-07-02   4.600000   4.620000   3.742000   3.840000  25699000          0
# 2010-07-06   4.000000   4.000000   3.166000   3.222000  34334500          0
# ...               ...        ...        ...        ...       ...        ...
# 2014-12-23  44.762001  44.863998  43.903999  44.194000  22528500          0
# 2014-12-24  43.953999  44.500000  43.849998  44.452000   6661000          0
# 2014-12-26  44.301998  45.700001  44.299999  45.563999  16635000          0
# 2014-12-29  45.380001  45.582001  44.804001  45.141998  14012500          0
# 2014-12-30  44.798000  45.130001  44.279999  44.445999  14516000          0
#
#             Stock Splits
# Date
# ...

# %%
#Set the stock symbols, data source, and time range
stocks = ['GOOGL', 'TM', 'KO', 'PEP']
numAssets = len(stocks)
source = 'yahoo'
start = '2010-01-01'
end = '2015-10-31'


#############

#data = yf.download("GOOGL TM KO PEP", start=start,end=end) 
#print(data['Close'])


##
#Retrieve stock price data and save just the dividend adjusted closing prices
for symbol in stocks:
    data = yf.download("GOOGL TM KO PEP", start=start,end=end) 
    
        #data[symbol] = web.DataReader(symbol, data_source=source, start=start, end=end)['Adj Close']

#Calculate simple linear returns
returns = (data - data.shift(1)) / data.shift(1)

#Calculate individual mean returns and covariance between the stocks
meanDailyReturns = returns.mean()
covMatrix = returns.cov()

#Calculate expected portfolio performance
weights = [0.5, 0.2, 0.2, 0.1]
portReturn = np.sum( meanDailyReturns*weights )
portStdDev = np.sqrt(np.dot(weights.T, np.dot(covMatrix, weights)))
# Out:
# [*********************100%***********************]  4 of 4 completed
# [*********************100%***********************]  4 of 4 completed
# [*********************100%***********************]  4 of 4 completed
# [*********************100%***********************]  4 of 4 completed
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-9cf84df175ad> in <module>
#      29 #Calculate expected portfolio performance
#      30 weights = [0.5, 0.2, 0.2, 0.1]
# ---> 31 portReturn = np.sum( meanDailyReturns*weights )
#      32 portStdDev = np.sqrt(np.dot(weights.T, np.dot(covMatrix, weights)))
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ...
